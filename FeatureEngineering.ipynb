# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("Student_performance_data .csv")
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
# Low correlation to target variable
df.drop(columns=['StudentID','Age','Gender','Ethnicity','ParentalEducation','Sports','Music','Volunteering','Tutoring','ParentalSupport'], inplace=True)

# %%
print('Skew')
for x in df.columns:
    print(df[x].name)
    print(df[x].skew())  
    print(' ')
# Out:
# Skew
# StudyTimeWeekly
# 0.05006807255835409
#
# Absences
# -0.026017090405395748
#
# Tutoring
# 0.8660445294904519
#
# ParentalSupport
# -0.16685872350058553
#
# Extracurricular
# 0.48009368751877385
#
# GPA
# 0.014525601346976225
#
# GradeClass
# -0.900807237222296

# %%
# for x in df.columns:
#     sns.FacetGrid(df, aspect=1.2).map(sns.histplot,x, bins=50, kde=True).add_legend()
#     print(df[x].value_counts(normalize=True))

# %%
scaler = StandardScaler()
df[['StudyTimeWeekly','Absences','GPA']] = scaler.fit_transform(df[['StudyTimeWeekly','Absences','GPA']])

# %%
for x in df[['StudyTimeWeekly','Absences','GPA']].columns:
    sns.FacetGrid(df, aspect=1.2).map(sns.histplot,x, bins=50, kde=True).add_legend()
